# %% [markdown]
# # Import Packages

# %%
from IPython.display import Image

# %% [markdown]
# # Part 1

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/GitHub/L09handson/01CreateLocal.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/GitHub/L09handson/02CreateLocal.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/GitHub/L09handson/03CreateProject.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/GitHub/L09handson/04CloneRepo.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/GitHub/L09handson/05PushOrigin.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/GitHub/L09handson/06GitHubConfirm.png')

# %% [markdown]
# # Part 2

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/GitHub/L09handson/07MergeConflict01.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/GitHub/L09handson/08MergeConflict02.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/GitHub/L09handson/09MergeConflict03.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/GitHub/L09handson/10MergeConflict04.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/GitHub/L09handson/11MergeConflict05.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/GitHub/L09handson/12MergeConflict06.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/GitHub/L09handson/13MergeConflict07.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/GitHub/L09handson/14MergeConflict08.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/GitHub/L09handson/14MergeConflict08.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/GitHub/L09handson/15MergeConflict09.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/GitHub/L09handson/16MergeConflict10.png')

# %%
Image(filename = '/Users/silviacatalina/Google Drive/BethelTech/GitHub/L09handson/17MergeConflict11.png')
